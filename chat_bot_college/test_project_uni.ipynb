# %%
from langchain_community.document_loaders.web_base import WebBaseLoader
from langchain_openai import ChatOpenAI
import os
import dotenv
from langchain_community.embeddings import HuggingFaceHubEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.chains.retrieval_qa.base import RetrievalQA
from langchain.prompts import PromptTemplate
from langchain.memory import ConversationBufferMemory
from langchain.chains.conversation.base import ConversationChain

dotenv.load_dotenv()

api_key = os.getenv("openaiKey")

chat = ChatOpenAI(model="gpt-4o",api_key=api_key)
memory = ConversationBufferMemory()

# %%
arquivos = ["https://www.iesp.edu.br/institucional/a-faculdade"
            ,"https://www.iesp.edu.br/polos"
            ,"https://www.iesp.edu.br/institucional/biblioteca"
            ,"https://www.iesp.edu.br/institucional/coopere",
            "https://www.iesp.edu.br/institucional/cpa",
            "https://www.iesp.edu.br/institucional/ceua",
            "https://www.iesp.edu.br/institucional/enade",
            "https://www.iesp.edu.br/institucional/comite-de-etica",
            "https://www.iesp.edu.br/institucional/dce-e-das",
            "https://www.iesp.edu.br/institucional/dirigentes",
            "https://www.iesp.edu.br/institucional/setores-e-telefones",
            "https://www.iesp.edu.br/institucional/dpo-lgpd",
            "https://www.iesp.edu.br/ingresso/inscreva-se",
            "https://www.iesp.edu.br/cursos/graduacao/modalidade/presencial",
            "https://www.iesp.edu.br/cursos/graduacao/administracao",
            "https://www.iesp.edu.br/cursos/graduacao/arquitetura-e-urbanismo",
            "https://www.iesp.edu.br/cursos/graduacao/biomedicina",
            "https://www.iesp.edu.br/cursos/graduacao/ciencias-contabeis",
            "https://www.iesp.edu.br/cursos/graduacao/ciencias-da-computacao",
            "https://www.iesp.edu.br/cursos/graduacao/design-de-interiores",
            "https://www.iesp.edu.br/cursos/graduacao/design-grafico",
            "https://www.iesp.edu.br/cursos/graduacao/direito",
            "https://www.iesp.edu.br/cursos/graduacao/educacao-fisica",
            "https://www.iesp.edu.br/cursos/graduacao/enfermagem",
            "https://www.iesp.edu.br/cursos/graduacao/engenharia-civil",
            "https://www.iesp.edu.br/cursos/graduacao/estetica-e-cosmetica",
            "https://www.iesp.edu.br/cursos/graduacao/farmacia",
            "https://www.iesp.edu.br/cursos/graduacao/fisioterapia",
            "https://www.iesp.edu.br/cursos/graduacao/gestao-comercial",
            "https://www.iesp.edu.br/cursos/graduacao/gestao-de-recursos-humanos",
            "https://www.iesp.edu.br/cursos/graduacao/gestao-financeira",
            "https://www.iesp.edu.br/cursos/graduacao/medicina-veterinaria",
            "https://www.iesp.edu.br/cursos/graduacao/nutricao",
            "https://www.iesp.edu.br/cursos/graduacao/odontologia",
            "https://www.iesp.edu.br/cursos/graduacao/producao-publicitaria",
            "https://www.iesp.edu.br/cursos/graduacao/psicologia",
            "https://www.iesp.edu.br/cursos/graduacao/publicidade-e-propaganda",
            "https://www.iesp.edu.br/cursos/graduacao/sistemas-para-internet",
            "https://www.iesp.edu.br/cursos/graduacao/modalidade/semipresencial",
            "https://www.iesp.edu.br/cursos/graduacao/licenciatura-em-pedagogia-semipresencial-",
            "https://www.iesp.edu.br/cursos/graduacao/modalidade/ead",
            "https://www.iesp.edu.br/cursos/graduacao/analise-e-desenvolvimento-de-sistemas-ead-",
            "https://www.iesp.edu.br/cursos/graduacao/gestao-da-tecnologia-da-informacao-ead-",
            "https://www.iesp.edu.br/cursos/graduacao/logistica-ead-",
            "https://www.iesp.edu.br/cursos/graduacao/marketing-ead-",
            "https://www.iesp.edu.br/cursos/pos-graduacao/modalidade/presencial",
            "https://www.iesp.edu.br/cursos/pos-graduacao/modalidade/ead",
            "https://www.iesp.edu.br/cursos/cursos-livres",
            "https://www.iesp.edu.br/cursos/cursos-livres",
            "https://www.iesp.edu.br/servicos/internacionalizacao",
            "https://www.iesp.edu.br/servicos/nucleo-de-carreiras",
            "https://www.iesp.edu.br/servicos/estagios",
            "https://www.iesp.edu.br/servicos/nups",
            "https://www.iesp.edu.br/servicos/clinicaescola",
            "https://www.iesp.edu.br/servicos/area-do-egresso"]

arquivos_lidos = ""

for arquivo in arquivos:
    loader = WebBaseLoader(arquivo)
    docs = loader.load()
    arquivos_lidos += docs[0].page_content

# %%
split = RecursiveCharacterTextSplitter(
    chunk_size=250,
    chunk_overlap = 50,
    separators=["\n\n","\n","","."," "]
)

text = split.split_text(text=arquivos_lidos)
text
# Out:
# ['Centro Universitário - Institucional | IESP agora é UNIESP Centro Universitário | Cursos de Graduação e Pós-Graduação\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInstitucional',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário',
#  'Calendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno\n\n\n\n\nInscreva-se',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula \n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\nEducação a Distância\nAtendimento ao Aluno\n\n\n\n\n\n\n\n\n\n\n×\n\n\nBuscar',
#  '×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nCentro Universitário\n\n\n\n\n\nHome\nInstitucional\nCentro Universitário',
#  'BEM-VINDO AO UNIESP\nA busca por uma educação de qualidade e pelo desenvolvimento profissional de nossos alunos\xa0é a meta que permeia todas as nossas atividades.',
#  'Colocadas diante de nós desde a fundação, em 8 de Setembro 1998,\xa0esses objetivos se refletem em uma estrutura física atraente e completa, com\xa0oito grandes blocos repletos de salas de aulas amplas e climatizadas; auditórios e laboratórios para as dis',
#  'limatizadas; auditórios e laboratórios para as discussões práticas da vida acadêmica; biblioteca com um dos melhores acervos da Paraíba; além de espaço de vivência com praça de alimentação e internet wi-fi.',
#  'Educação de qualidade também não existiria sem um corpo docente de excelente bagagem acadêmica e profissional, formado por especialistas, mestres e doutores, que promovem aulas aprofundadas e dinâmicas. Aliado aos nossos professores, há o empenho co',
#  'as. Aliado aos nossos professores, há o empenho constante das Coordenações em prover a nossos alunos eventos e palestras que complementem a sua formação.',
#  'É no aperfeiçoamento constante de nossa estrutura, de nossos professores e de nossas atividades que buscamos superar nossas metas, com ganhos reais para aqueles que detêm toda a nossa atenção: os alunos e alunas que crescem conosco em sua vida acadê',
#  'nos e alunas que crescem conosco em sua vida acadêmica e profissional.',
#  'REGIMENTO GERALMANUAL DO ALUNO',
#  'Missão\nDesenvolver e Conectar pessoas, mediante experiências educacionais transformadoras, para melhorar o mundo.',
#  'Visão\nAté 2025, o UNIESP será a instituição de educação superior mais desejada do estado da Paraíba, reconhecida por promover excelência acadêmica, soluções inovadoras e experiências memoráveis.\n\n\n\n\n\n\n\n\n\n\n\n\nESTRUTURA',
#  'ESTRUTURA\n\n\n\nBLOCOS\nSALAS DE AULA TEÓRICA E PRÁTICA\nCLÍNICA E LABORATÓRIOS DE SAÚDE\nBIBLIOTECA\nAUDITÓRIOS\nESTACIONAMENTO\nÁREAS DE VIVÊNCIA\nESPAÇO INOVA\nPAREDÃO DE ESCALADA\nCAMPO',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS',
#  'Dirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula PRAVALER\n\n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\n\n\n\n\nCopyright ©2025 Sociedade de Ensino Superior da Paraíba Sociedade Simples LTDA',
#  'Polos - Institucional | IESP agora é UNIESP Centro Universitário | Cursos de Graduação e Pós-Graduação',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD',
#  'Dirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula \n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\nEducação a Distância\nAtendimento ao Aluno\n\n\n\n\n\n\n\n\n\n\n×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nPolos',
#  '×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nPolos\n\n\n\n\n\nHome\nInstitucional\nPolos\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJoão Pessoa\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCampina Grande\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPatos\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInstitucional',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário',
#  'Calendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula PRAVALER\n\n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\n\n\n\n\nCopyright ©2025 Sociedade de Ensino Superior da Paraíba Sociedade Simples LTDA',
#  'Biblioteca Padre Joaquim Colaço - Institucional | IESP agora é UNIESP Centro Universitário | Cursos de Graduação e Pós-Graduação',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS',
#  'Dirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula \n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\nEducação a Distância\nAtendimento ao Aluno\n\n\n\n\n\n\n\n\n\n\n×\n\n\nBuscar',
#  '×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nBiblioteca Padre Joaquim Colaço\n\n\n\n\n\nHome\nInstitucional\nBiblioteca',
#  'SOBRE A BIBLIOTECA',
#  'A Biblioteca constitui um órgão central de suporte aos planos e programas acadêmicos do\xa0UNIESP, estimulando o ensino, a pesquisa e a extensão. Conta com uma área fixa de aproximadamente 2.216m², sendo 1.206m² destinado à área do acervo e 1.010m² à á',
#  'o 1.206m² destinado à área do acervo e 1.010m² à área para estudo e usuários. Dispõe de salas para estudo individual, salas de estudo em grupo, sala de leitura, sala de periódicos e sala de multimídia destinada à pesquisa virtual e acadêmica, com ace',
#  'destinada à pesquisa virtual e acadêmica, com acesso as Bases de Dados de Livros e Periódicos Eletrônicos, entre outras bases.',
#  'Seu acervo é composto por aproximadamente 60.000 exemplares de livros, periódicos, CDs, DVD’s, trabalhos de conclusão de curso, entre outros; todos distribuídos nas áreas de Ciências Sociais Aplicadas; Ciências Humanas; Linguística, Letras e Artes;',
#  's; Ciências Humanas; Linguística, Letras e Artes; Ciências Exatas e da Terra; Ciências da Saúde e Engenharias.',
#  'A biblioteca é de livre acesso a toda comunidade acadêmica, sendo eles estudantes matriculados na instituição, professores, funcionários e o público externo. Conta com uma política de desenvolvimento e atualização das coleções. A aquisição do acervo',
#  'e atualização das coleções. A aquisição do acervo é realizada semestralmente, atendendo as bibliografias básicas e complementares dos projetos pedagógicos dos cursos.',
#  'O atendimento é especializado por profissionais bibliotecários e auxiliares técnico-administrativos, capacitados para atender as expectativas e necessidades informacionais, na consulta e utilização dos produtos e serviços oferecidos, sempre buscando',
#  'os produtos e serviços oferecidos, sempre buscando a excelência e qualidade.',
#  'O livre acesso a biblioteca é destinado ao público em geral para consulta local, sendo o empréstimo domiciliar privativo aos docentes, discentes e funcionários devidamente vinculados à Instituição.\nACESSE AQUI O REGULAMENTO DA BIBLIOTECA',
#  'ACESSE AQUI O REGULAMENTO DA BIBLIOTECA\nMANUAL DE USO DA BIBLIOTECA\nPROJETO CLUBE DO LIVRO',
#  'SERVIÇOS OFERECIDOS:',
#  'Consulta online e presencial\nEmpréstimo domiciliar\nReservas e Renovação online e presencial\nAtendimento e orientação para pesquisa e elaboração de trabalhos acadêmicos\nLevantamento bibliográfico\nCatalogação na fonte',
#  'Levantamento bibliográfico\nCatalogação na fonte\nVisitas dirigidas (sala de aula, auditório e dependências da Biblioteca)\nDisseminação seletiva da informação\nDivulgação e Marketing\nReferência (setor de informação ao usuário)\nEspaço para Leitura',
#  'Espaço para Leitura\nAcesso a rede Wi-Fi',
#  'Normas Gerais:\n\n\n\n\nCadastro',
#  'Para realizar o empréstimo do material bibliográfico, o usuário deverá realizar o cadastro na biblioteca.O cadastro é permitido aos alunos devidamente matriculados, professores e funcionários vinculados à instituição, como também a comunidade extern',
#  'dos à instituição, como também a comunidade externa (visitantes), basta preencher o formulário eletrônico disponível nesta página.O acesso ao ambiente físico é permitido mediante cadastrado da biometria na catraca eletrônica.',
#  'Empréstimo',
#  'O empréstimo do material bibliográfico é permitido apenas aos alunos regularmente matriculados, e, professores e funcionários vinculados à instituição.\n\xa0\nPolítica de Empréstimo:',
#  'Política de Empréstimo:\n\xa0Aluno da graduação:\xa05 livros - 10 dias corridos Aluno concluinte e pós-graduação: 7 livros - 15 dias corridos Professor: 10 livros - 30 dias corridos\nFuncionário: 5 livros - 10 dias corridos',
#  'Funcionário: 5 livros - 10 dias corridos\n\xa0*Após o prazo previsto para a devolução, será cobrada uma multa diária de R$2,00 (dois reais) por dia e por livro.',
#  'Usuário visitante',
#  'À comunidade externa (usuário visitante) é permitido utilizar o ambiente da biblioteca e a consulta local do material bibliográfico, mediante preenchimento do formulário eletrônico, sendo renovado a cada semestre.\n\xa0\nPolítica de Visitante:',
#  'Política de Visitante:\n\xa0- Inscrição semestral pela internet através do formulário eletrônico\n- Pagamento de taxa prevista no regulamento da biblioteca\n- Cadastro da biometria na catraca eletrônica',
#  'Renovação e reservas\n\n\n\n\nRenovação:',
#  'A renovação do material emprestado deverá ser feita nos computadores da biblioteca ou na internet, mediante matrícula e senha;',
#  'A data prevista para devolução após a renovação corresponde ao mesmo período do empréstimo inicial, a contar da data que o livro foi renovado, conforme política de empréstimo;',
#  'O usuário não poderá renovar o empréstimo se estiver em débito, ou se a obra estiver reservada por terceiros;',
#  'Em caso de falha na conexão, site não disponível ou outro problema que impossibilite a utilização deste recurso, a biblioteca não se responsabiliza pelo atraso do livro;',
#  'A renovação online poderá ser feita até três vezes consecutivas. Após este limite, o usuário deverá comparecer na biblioteca.',
#  'Reserva:',
#  'A reserva é feita online e obedece a ordem cronológica;\nSó poderá ser reservado o material bibliográfico que não esteja disponível na biblioteca;\nOs livros reservados não poderão ser usados para consulta local ou xerox;',
#  'A reserva do material permanece até 48 horas, caso o usuário não venha pegar o livro, o mesmo é passado para o próximo da fila.',
#  'Atividades Práticas',
#  'A Biblioteca Padre Dourado oferece uma ampla estrutura, serviços e recursos que atendem as necessidades informacionais dos nossos usuários, disponibilizando ambientes para aulas, treinamentos e visitas dirigidas, como suporte no ensino-aprendizagem',
#  'as dirigidas, como suporte no ensino-aprendizagem de nossa IES.',
#  'Espaços disponíveis para atividades educacionais, e suas características específicas:',
#  'Sala de Leitura:\xa0Este ambiente se destaca por seu formato, despertando o ócio criativo. Com característica descontraída, dispõe de mesas e cadeiras, estantes, Datashow com tela de projeção para apresentações interativas, redes, pufes e carpete verde',
#  'entações interativas, redes, pufes e carpete verde, proporcionando um ambiente acolhedor.',
#  'Sala de Multimídia:\xa0Projetada para atividades envolvendo tecnologia, essa sala possui 24 computadores distribuídos em seis ilhas,\xa0Datashow e tela de projeção. Cada estação permite a realização de atividades virtuais de maneira eficaz e colaborativa,',
#  'vidades virtuais de maneira eficaz e colaborativa, com acesso a bases de dados e programas que auxiliam no desenvolvimento de projetos, trabalhos e pesquisas.',
#  'Sala de Estudos em Grupo:\xa0A biblioteca dispõe de oito salas de estudo em grupo, destinadas à grupos que estão desenvolvendo trabalhos em conjunto e troca de ideias. Cada sala está equipada com mesa e seis cadeiras, quadro branco, pincel marcador e a',
#  'seis cadeiras, quadro branco, pincel marcador e apagador, que auxiliam o estudo e a monitoria, quando for o caso.',
#  'Ambiente geral/ Acervo: Agendamentos para grupos e professores que desejam conhecer os ambientes da biblioteca e o acervo, por meio de visita dirigida.',
#  'Ambiente de Jogo de Xadrez: Este ambiente é destinado aos amantes do xadrez, que desejam aprender ou treinar suas habilidades, despertando o pensamento lógico, estratégico e a concentração nos estudos.',
#  'Nossa intenção é criar um ambiente propício para a construção do conhecimento, de maneira dinâmica e interativa. Convidamos alunos e educadores a explorar esses espaços, desfrutando o máximo proveito das instalações que oferecemos. Estamos compromet',
#  'das instalações que oferecemos. Estamos comprometidos em colaborar com o ensino-aprendizagem e a experiência educacional, por meio de nossa estrutura e ambientes, cuidadosamente projetados para atender as expectativas de nossos usuários.',
#  'ESTRUTURA ADMINISTRATIVA\n\n \n\n\n\n\n\nElaine Cristina de Brito Moreira\n\nCoordenação - CRB-15/053\n\n\n\n\n\n\n\n\n\n\n\nElisangela Gomes da Silva\n\nEquipe Técnica-Administrativa\n\n\n\n\n\n\n\n\n\n\n\nJoana Paula de Oliveira\n\nAssistente Administrativo',
#  'Assistente Administrativo \n\n\n\n\n\n \n\n\n\n\n\nNatália da Conceição Machado\n\nEquipe Técnica-Administrativa\n\n\n\n\n\n\n\n\n\n\n\nCristiane das Graças do Nascimento Allem\n\nEquipe Técnica-Administrativa\n\n\n\n\n\n\n\n\n\n\n\nHanielly Silva Marques\n\nEquipe Técnica-Administrativa',
#  'Equipe Técnica-Administrativa\n\n\n\n\n\n \n\n\n\n\n\n\n\nPORTAL SIABI WEB\n\n\nCONSULTA  AO ACERVO\nCADASTRO DO USUÁRIO\nÁREA DO USUÁRIO\nDESTAQUES DO ACERVO\nLINKS\nNOTÍCIAS\nFALE CONOSCO\nTUTORIAL DAS BASES DE DADOS\nTERMO DE DOAÇÃO\nCADASTRO DE USUÁRIO VISITANTE',
#  'Bibliotecas Digitais\n\nNeste espaço você poderá acessar as bases de dados de livros, periódicos e normas da ABNT. O acesso é restrito a alunos e professores vinculados à instituição.',
#  'MINHA BIBLIOTECA\nMINHA BIBLIOTECA MED/ODONTO\nPERIÓDICOS EBSCO\nNORMAS TÉC. TARGED GEDWEB\n\n\n\n\nSOLICITE SEU ACESSO AQUI\n\n\n\n\nAmbiente Virtual\n\n\n\n\t\t\t\t\t\t\t\t\tBiblioteca Virtual - SESP\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tPeriódicos Capes',
#  'Periódicos Capes\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tObjetos de Aprendizagem\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tPublicações Científicas\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tRevistas Científicas - Open access\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tPortais e Fontes de Pesquisa\t\t\t\t\t\t\t\t\n\n\n\n\nHorários',
#  'Horários de Funcionamento da Biblioteca: \n Segunda a sexta: 8h00 às 21h00  Sábados: 8h00 às 12h00 \n (83) 2106-3819  Geral: biblioteca@iesp.edu.br  Referência: bibliotecareferencia@iesp.edu.br',
#  'Sociedade de Ensino Superior da Paraíba. Br 230, Km14 - Estrada de Cabedelo. Bloco  Central – 1º e 2º Andares.',
#  'Agendamento\n\nAgende o serviço de seu interesse:\n\nAtividades Práticas\nSala de Estudo em Grupo\nAmbiente de Estudo Individual\nComputadores da Multimídia\n\n\n\n\n\n\nNormas para TCC',
#  'Normas para TCC\n\n\nSolicitação de Ficha Catalográfica\nLei do Depósito Legal\nNormas TCC UNIESP\nModelo de Capa de DVD\nNormas para Ficha Catalográfica\n\n\n\n\n\nTUTORIAIS',
#  'PESQUISA A BIBLIOTECA VIRTUAL - MINHA BIBLIOTECA\nPesquisa a Base de Dados de Periódicos - EBSCO\nPesquisa a Base de Normas Técnicas - Gedweb\nPesquisa ao Banco de Dados da Biblioteca\nComo o Acervo é Organizado\nComo Encontrar os Livros nas Estantes',
#  'Como Encontrar os Livros nas Estantes\nComo Fazer Renovações Online\nRevista dos Tribunais - Guia de Uso\n Pesquisa a Base de Dados - Revista dos Tribunais\nMANUAL DE USO DA BIBLIOTECA',
#  'Ambientes\n\n\nSalas de estudo indivudual e em grupo\nSala de Multimídia\nSala de Períodicos e TCC\nSala de Trabalhos de Conclusão de Curso\nAcervo geral\nTerminais de Consulta ao Acervo\nCabines para Estudo\nSala de Leitura\n\n\n\n\n\nGaleria',
#  'Galeria\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAcervo\n\n\nLivros impressos e Online\nPeriódicos impressos e Online\nMultimídia (E-books, CD, DVD, Audiolivro)\nTrabalhos de Conclusão de Cursos\n\n\n\n\n\n\n\n\n\n\n×\n\n\n\n\n\n\n\nAGENDAMENTO PARA VISITA DIRIGIDA',
#  '×\n\n\n\n\n\n\n\nAGENDAMENTO PARA VISITA DIRIGIDA\n\n\n\n\nEnviando agendamento...\n\n\nAgendamento enviado com sucesso\n\n\nFalha ao enviar agendamento.\n\n\nFalha reCAPTCHA: Marque "Não sou robô" para continuar.\n\n\nFalha reCAPTCHA: Inválido. Tente novamente.',
#  'Falha reCAPTCHA: Inválido. Tente novamente.\n\n\n\n\n\n\nLocal\nBiblioteca\nSala de Aula\nAuditório',
#  'Curso\n MBA Executivo em Gestão de Negócios, Consultoria e Inteligência Mercadológica\nAdministração\nAdministração - EAD\nAdministração Escolar (EAD)\nAnálise do Comportamento Aplicada\nAnálise e Desenvolvimento de Sistemas (EAD)\nArquitetura e Urbanismo',
#  'Arquitetura e Urbanismo\nArte Contemporânea\nAtividade Física e Saúde para o Idoso \nAtividades Físicas e Danças em Academias de Ginástica\nAuditoria, Avaliações e Legislação para Engenheiros (EAD)\nAvaliação de Imóveis',
#  'Avaliação de Imóveis\nAvaliação e Intervenção Psicopedagógica e Neuropsicopedagogica na Prática\nAvaliação Psicológica e Psicodiagnóstico \nBiomedicina\nCiências Contábeis\nCiências Contábeis - EAD\nCiências da Computação\nComputação Gráfica e Multimídias',
#  'Computação Gráfica e Multimídias\nComunicação e Marketing Pessoal (EAD)\nCoordenação, Supervisão e Gestão Educacional \nCusto e formação de preço\nCybersecurity\nDesafios Contemporâneos e Inovação na Gestão Pública\nDesign de Interiores',
#  'Design de Interiores\nDesign e Inovação de Interiores\nDesign Gráfico\nDigital Design\nDireito\nDireito do Trabalho e Previdenciário\nDireito Processual Civil\nDireito Tributário na Prática\nDocência no Ensino Superior (EAD)\nEconomia Política',
#  'Economia Política \nEducação Especial e Inclusiva (EAD)\nEducação Física\nEducação Física (SEMIPRESENCIAL)\nEducação Infantil (EAD)\nEnfermagem\nEnfermagem em Estomaterapia\nEngenharia Civil\nEngenharia de Segurança do Trabalho \nEscrita Criativa',
#  'Escrita Criativa\nEspecialização e Recreação, Lazer, Jogos e Brincadeiras na Escola \nEspecialização em Alfabetização e Letramento (EAD)\nEspecialização em Audiologia\nEspecialização em Ciências Criminais, Perícia e Segurança Pública',
#  'Especialização em Confeitaria e Panificação Inclusivas\nEspecialização em Desenvolvimento de Software para Sistemas Web\nEspecialização em Design de Mobiliário\nEspecialização em Direito e Processo Eleitoral\nEspecialização em Doenças Raras',
#  'Especialização em Doenças Raras\nEspecialização em Educação Física e Saúde Integrativa: Atuação clínica e hospitalar\nEspecialização em Enfermagem em UTI Adulto e Urgência e Emergência\nEspecialização em Gestão Escolar (EAD)',
#  'Especialização em Gestão Escolar (EAD)\nEspecialização em Harmonização Orofacial \nEspecialização em Metodologia do Ensino dos Esportes na Escola \nEspecialização em Naturopatia e Bem Estar Integrativo\nEspecialização em Ortodontia',
#  'Especialização em Ortodontia\nEspecialização em Prótese Dentária\nEspecialização em Quality Assurance e Robotic Process Automation\nEspecialização em Sucessão Empresarial em Empresas Familiares\nEstética e Cosmética\nEstética e História da Arte',
#  'Estética e Cosmética\nEstética e História da Arte\nEstratégia de marketing\nEthical Hacking e Cybersecurity\nExercício e Treinamento Desportivo\nExercícios Físicos e o idoso\nFarmácia\nFarmácia Clínica e Hospitalar com Ênfase em Prescrição Farmacêutica',
#  'Farmácia Oncológica\nFisiologia, Exercício Físico e Treinamento \nFisioterapia\nFisioterapia em Terapia Intensiva: Adulto e Pediátrica\nFitoterapia\nFonoaudiologia hospitalar e Disfagia\nFonoaudiologia: Linguagem\nFull Stack Web Development',
#  'Full Stack Web Development\nGeometria Espacial\nGestão Ágil de Projetos de Design\nGestão Comercial\nGestão Comercial (EAD)\nGestão da Qualidade e Produtividade\nGestão da Tecnologia da Informação (EAD)\nGestão de compras e fornecedores',
#  'Gestão de compras e fornecedores\nGestão de Conhecimento, Inteligência e Contrainteligência\nGestão de Contas Públicas (EAD)\nGestão de Logística em Atavarejo (EAD)\nGestão de Negócios Digitais e Comércio Eletrônico\nGestão de Negócios Web e Gamificação',
#  'Gestão de Negócios Web e Gamificação\nGestão de Operações Logísticas\nGestão de Pessoas\nGESTÃO DE PROCESSOS DE INOVAÇÃO \nGestão de Produtos e Serviços (EAD)\nGestão de Projetos (EAD)\nGestão de Recursos Humanos\nGestão de Recursos Humanos (EAD)',
#  'Gestão de Recursos Humanos (EAD)\nGestão de Relacionamento com o Cliente\nGESTÃO DE SEGURANÇA PÚBLICA E PRIVADA  \nGestão de Serviços de Farmácia',
#  'Agendar\n\n\n\n\n\n\n\n\n\n×\n\n\n\n\n\n\n\nAGENDAMENTO PARA SALA DE ESTUDO EM GRUPO\n\n\n\n\nEnviando agendamento...\n\n\nAgendamento enviado com sucesso\n\n\nFalha ao enviar agendamento.',
#  'Falha ao enviar agendamento.\n\n\nFalha reCAPTCHA: Marque "Não sou robô" para continuar.\n\n\nFalha reCAPTCHA: Inválido. Tente novamente.',
#  'Curso\n MBA Executivo em Gestão de Negócios, Consultoria e Inteligência Mercadológica\nAdministração\nAdministração - EAD\nAdministração Escolar (EAD)\nAnálise do Comportamento Aplicada\nAnálise e Desenvolvimento de Sistemas (EAD)\nArquitetura e Urbanismo',
#  'Arquitetura e Urbanismo\nArte Contemporânea\nAtividade Física e Saúde para o Idoso \nAtividades Físicas e Danças em Academias de Ginástica\nAuditoria, Avaliações e Legislação para Engenheiros (EAD)\nAvaliação de Imóveis',
#  'Avaliação de Imóveis\nAvaliação e Intervenção Psicopedagógica e Neuropsicopedagogica na Prática\nAvaliação Psicológica e Psicodiagnóstico \nBiomedicina\nCiências Contábeis\nCiências Contábeis - EAD\nCiências da Computação\nComputação Gráfica e Multimídias',
#  'Computação Gráfica e Multimídias\nComunicação e Marketing Pessoal (EAD)\nCoordenação, Supervisão e Gestão Educacional \nCusto e formação de preço\nCybersecurity\nDesafios Contemporâneos e Inovação na Gestão Pública\nDesign de Interiores',
#  'Design de Interiores\nDesign e Inovação de Interiores\nDesign Gráfico\nDigital Design\nDireito\nDireito do Trabalho e Previdenciário\nDireito Processual Civil\nDireito Tributário na Prática\nDocência no Ensino Superior (EAD)\nEconomia Política',
#  'Economia Política \nEducação Especial e Inclusiva (EAD)\nEducação Física\nEducação Física (SEMIPRESENCIAL)\nEducação Infantil (EAD)\nEnfermagem\nEnfermagem em Estomaterapia\nEngenharia Civil\nEngenharia de Segurança do Trabalho \nEscrita Criativa',
#  'Escrita Criativa\nEspecialização e Recreação, Lazer, Jogos e Brincadeiras na Escola \nEspecialização em Alfabetização e Letramento (EAD)\nEspecialização em Audiologia\nEspecialização em Ciências Criminais, Perícia e Segurança Pública',
#  'Especialização em Confeitaria e Panificação Inclusivas\nEspecialização em Desenvolvimento de Software para Sistemas Web\nEspecialização em Design de Mobiliário\nEspecialização em Direito e Processo Eleitoral\nEspecialização em Doenças Raras',
#  'Especialização em Doenças Raras\nEspecialização em Educação Física e Saúde Integrativa: Atuação clínica e hospitalar\nEspecialização em Enfermagem em UTI Adulto e Urgência e Emergência\nEspecialização em Gestão Escolar (EAD)',
#  'Especialização em Gestão Escolar (EAD)\nEspecialização em Harmonização Orofacial \nEspecialização em Metodologia do Ensino dos Esportes na Escola \nEspecialização em Naturopatia e Bem Estar Integrativo\nEspecialização em Ortodontia',
#  'Especialização em Ortodontia\nEspecialização em Prótese Dentária\nEspecialização em Quality Assurance e Robotic Process Automation\nEspecialização em Sucessão Empresarial em Empresas Familiares\nEstética e Cosmética\nEstética e História da Arte',
#  'Estética e Cosmética\nEstética e História da Arte\nEstratégia de marketing\nEthical Hacking e Cybersecurity\nExercício e Treinamento Desportivo\nExercícios Físicos e o idoso\nFarmácia\nFarmácia Clínica e Hospitalar com Ênfase em Prescrição Farmacêutica',
#  'Farmácia Oncológica\nFisiologia, Exercício Físico e Treinamento \nFisioterapia\nFisioterapia em Terapia Intensiva: Adulto e Pediátrica\nFitoterapia\nFonoaudiologia hospitalar e Disfagia\nFonoaudiologia: Linguagem\nFull Stack Web Development',
#  'Full Stack Web Development\nGeometria Espacial\nGestão Ágil de Projetos de Design\nGestão Comercial\nGestão Comercial (EAD)\nGestão da Qualidade e Produtividade\nGestão da Tecnologia da Informação (EAD)\nGestão de compras e fornecedores',
#  'Gestão de compras e fornecedores\nGestão de Conhecimento, Inteligência e Contrainteligência\nGestão de Contas Públicas (EAD)\nGestão de Logística em Atavarejo (EAD)\nGestão de Negócios Digitais e Comércio Eletrônico\nGestão de Negócios Web e Gamificação',
#  'Gestão de Negócios Web e Gamificação\nGestão de Operações Logísticas\nGestão de Pessoas\nGESTÃO DE PROCESSOS DE INOVAÇÃO \nGestão de Produtos e Serviços (EAD)\nGestão de Projetos (EAD)\nGestão de Recursos Humanos\nGestão de Recursos Humanos (EAD)',
#  'Gestão de Recursos Humanos (EAD)\nGestão de Relacionamento com o Cliente\nGESTÃO DE SEGURANÇA PÚBLICA E PRIVADA  \nGestão de Serviços de Farmácia',
#  'Horário\nSeg. a Sex. - 7:30 às 9:30 h\nSeg. a Sex. - 9:30 às 11:30 h\nSeg. a Sex. - 11:30 às 13:30 h\nSeg. a Sex. - 13:30 às 15:30 h\nSeg. a Sex. - 15:30 às 17:30 h\nSeg. a Sex. - 17:30 às 19:30 h\nSeg. a Sex. - 19:30 às 21:30 h\nSábado - 8:00 às 10:00 h',
#  'Sábado - 8:00 às 10:00 h\nSábado - 10:00 às 12:00 h\nSábado - 12:00 às 14:00 h',
#  'Agendar\n\n\n\n\n\n\n\n\n\n×\n\n\n\n\n\n\n\nAGENDAMENTO PARA UTILIZAÇÃO DA MULTIMÍDIA\n\n\n\n\nEnviando agendamento...\n\n\nAgendamento enviado com sucesso\n\n\nFalha ao enviar agendamento.\n\n\nFalha reCAPTCHA: Marque "Não sou robô" para continuar.',
#  'Falha reCAPTCHA: Inválido. Tente novamente.',
#  'Curso\n MBA Executivo em Gestão de Negócios, Consultoria e Inteligência Mercadológica\nAdministração\nAdministração - EAD\nAdministração Escolar (EAD)\nAnálise do Comportamento Aplicada\nAnálise e Desenvolvimento de Sistemas (EAD)\nArquitetura e Urbanismo',
#  'Arquitetura e Urbanismo\nArte Contemporânea\nAtividade Física e Saúde para o Idoso \nAtividades Físicas e Danças em Academias de Ginástica\nAuditoria, Avaliações e Legislação para Engenheiros (EAD)\nAvaliação de Imóveis',
#  'Avaliação de Imóveis\nAvaliação e Intervenção Psicopedagógica e Neuropsicopedagogica na Prática\nAvaliação Psicológica e Psicodiagnóstico \nBiomedicina\nCiências Contábeis\nCiências Contábeis - EAD\nCiências da Computação\nComputação Gráfica e Multimídias',
#  'Computação Gráfica e Multimídias\nComunicação e Marketing Pessoal (EAD)\nCoordenação, Supervisão e Gestão Educacional \nCusto e formação de preço\nCybersecurity\nDesafios Contemporâneos e Inovação na Gestão Pública\nDesign de Interiores',
#  'Design de Interiores\nDesign e Inovação de Interiores\nDesign Gráfico\nDigital Design\nDireito\nDireito do Trabalho e Previdenciário\nDireito Processual Civil\nDireito Tributário na Prática\nDocência no Ensino Superior (EAD)\nEconomia Política',
#  'Economia Política \nEducação Especial e Inclusiva (EAD)\nEducação Física\nEducação Física (SEMIPRESENCIAL)\nEducação Infantil (EAD)\nEnfermagem\nEnfermagem em Estomaterapia\nEngenharia Civil\nEngenharia de Segurança do Trabalho \nEscrita Criativa',
#  'Escrita Criativa\nEspecialização e Recreação, Lazer, Jogos e Brincadeiras na Escola \nEspecialização em Alfabetização e Letramento (EAD)\nEspecialização em Audiologia\nEspecialização em Ciências Criminais, Perícia e Segurança Pública',
#  'Especialização em Confeitaria e Panificação Inclusivas\nEspecialização em Desenvolvimento de Software para Sistemas Web\nEspecialização em Design de Mobiliário\nEspecialização em Direito e Processo Eleitoral\nEspecialização em Doenças Raras',
#  'Especialização em Doenças Raras\nEspecialização em Educação Física e Saúde Integrativa: Atuação clínica e hospitalar\nEspecialização em Enfermagem em UTI Adulto e Urgência e Emergência\nEspecialização em Gestão Escolar (EAD)',
#  'Especialização em Gestão Escolar (EAD)\nEspecialização em Harmonização Orofacial \nEspecialização em Metodologia do Ensino dos Esportes na Escola \nEspecialização em Naturopatia e Bem Estar Integrativo\nEspecialização em Ortodontia',
#  'Especialização em Ortodontia\nEspecialização em Prótese Dentária\nEspecialização em Quality Assurance e Robotic Process Automation\nEspecialização em Sucessão Empresarial em Empresas Familiares\nEstética e Cosmética\nEstética e História da Arte',
#  'Estética e Cosmética\nEstética e História da Arte\nEstratégia de marketing\nEthical Hacking e Cybersecurity\nExercício e Treinamento Desportivo\nExercícios Físicos e o idoso\nFarmácia\nFarmácia Clínica e Hospitalar com Ênfase em Prescrição Farmacêutica',
#  'Farmácia Oncológica\nFisiologia, Exercício Físico e Treinamento \nFisioterapia\nFisioterapia em Terapia Intensiva: Adulto e Pediátrica\nFitoterapia\nFonoaudiologia hospitalar e Disfagia\nFonoaudiologia: Linguagem\nFull Stack Web Development',
#  'Full Stack Web Development\nGeometria Espacial\nGestão Ágil de Projetos de Design\nGestão Comercial\nGestão Comercial (EAD)\nGestão da Qualidade e Produtividade\nGestão da Tecnologia da Informação (EAD)\nGestão de compras e fornecedores',
#  'Gestão de compras e fornecedores\nGestão de Conhecimento, Inteligência e Contrainteligência\nGestão de Contas Públicas (EAD)\nGestão de Logística em Atavarejo (EAD)\nGestão de Negócios Digitais e Comércio Eletrônico\nGestão de Negócios Web e Gamificação',
#  'Gestão de Negócios Web e Gamificação\nGestão de Operações Logísticas\nGestão de Pessoas\nGESTÃO DE PROCESSOS DE INOVAÇÃO \nGestão de Produtos e Serviços (EAD)\nGestão de Projetos (EAD)\nGestão de Recursos Humanos\nGestão de Recursos Humanos (EAD)',
#  'Gestão de Recursos Humanos (EAD)\nGestão de Relacionamento com o Cliente\nGESTÃO DE SEGURANÇA PÚBLICA E PRIVADA  \nGestão de Serviços de Farmácia',
#  'Horário\nSeg. a Sex. - 7:30 às 9:30 h\nSeg. a Sex. - 9:30 às 11:30 h\nSeg. a Sex. - 11:30 às 13:30 h\nSeg. a Sex. - 13:30 às 15:30 h\nSeg. a Sex. - 15:30 às 17:30 h\nSeg. a Sex. - 17:30 às 19:30 h\nSeg. a Sex. - 19:30 às 21:30 h\nSábado - 8:00 às 10:00 h',
#  'Sábado - 8:00 às 10:00 h\nSábado - 10:00 às 12:00 h\nSábado - 12:00 às 14:00 h',
#  'Computador\nPC 01\nPC 02\nPC 03\nPC 04\nPC 05\nPC 06\nPC 07\nPC 08\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAgendar\n\n\n\n\n\n\n\n\n\n×\n\n\n\n\n\n\n\nACESSO RESTRITO\n\n\n\n\n Aguarde um instante, validando dados...\n\n\n Acesso permitido, redirecionando...\n\n\n Acesso negado, tente novamente...',
#  'Acesso negado, tente novamente...\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAcessar\n\n\n\n\n\n\n\n\n\n\n×\n\n\n\n\n\n\n\nMinha Biblioteca\n\n\n\n\n Aguarde um instante, validando dados...\n\n\n Acesso permitido, redirecionando...\n\n\n Acesso negado, tente novamente...\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAcessar',
#  'Acessar\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInstitucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD',
#  'Dirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula PRAVALER\n\n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\n\n\n\n\nCopyright ©2025 Sociedade de Ensino Superior da Paraíba Sociedade Simples LTDA',
#  'COOPERE - Institucional | IESP agora é UNIESP Centro Universitário | Cursos de Graduação e Pós-Graduação',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD',
#  'Dirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula \n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\nEducação a Distância\nAtendimento ao Aluno\n\n\n\n\n\n\n\n\n\n\n×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nCOOPERE',
#  '×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nCOOPERE\n\n\n\n\n\nHome\nInstitucional\nCOOPERE',
#  'O Centro Universitário - UNIESP, objetivando desenvolver as políticas educacionais de forma efetiva institui a COOPERE com objetivos de Incentivar a Iniciação Científica, a Extensão, a Responsabilidade Social e a produção acadêmica através do estimu',
#  'de Social e a produção acadêmica através do estimulo aos docentes e discentes. A COOPERE tem a função de normatizar e regulamentar todas as ações ligadas a Iniciação Científica, Extensão, Responsabilidade Social e a Produção Acadêmica no âmbito do UN',
#  'dade Social e a Produção Acadêmica no âmbito do UNIESP.',
#  'A COOPERE faz parte do processo educativo, cultural e científico que articula o Ensino, Extensão, Pesquisa e Responsabilidade Social de forma interdisciplinar e indissociável e que apresenta ações transformadoras entre o Centro Universitário e a soc',
#  'ansformadoras entre o Centro Universitário e a sociedade de seu entorno, com base no diálogo entre os diversos saberes, interferindo diretamente na produção do conhecimento resultante da realidade, a democratização do conhecimento acadêmico e a parti',
#  'democratização do conhecimento acadêmico e a participação efetiva da comunidade.',
#  'EXTENSÃO\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAssistência Interdisciplinar ao Idoso em nível primário: enfoque do cirurgião-dentista. Orientação higiene bucal - Professora Erika Lira de Oliveira',
#  'Construindo a Arte de "Envelhe-Ser" - Professora Denise Reinaldo Pereira Ramos',
#  'CORAL UNIESP - Professor Almir Oliveira Salgueiro',
#  'Educação Nutricional em Creches: Uma Estratégia de Promoção a Saúde - Professora Zianne Farias Barros Barbosa',
#  'Ginástica de Academia/ UNIESP DANCE - Professor Wellington Cavalcanti de Araújo',
#  'Ginástica Laboral - Professor Wellington Cavalcanti de Araújo',
#  'Humanizado com Alegrai e Arte: Ações Desenvolvidas Por Estudantes de Enfermagem',
#  'Influência dos Cuidados Básicos, Assistência e Promoção da Saúde Com Idosos Abrigados em Instituição de Longa Permanência / Abrigo, e Melhora da Qualidade de Vida - Professora Gabriela Melo de Andrade',
#  'fessora Gabriela Melo de Andrade',
#  'Interdisciplinar idade na Saúde do Idoso: Diagnóstico nutricional / educação nutricional - Professora Kelly Cristina Muniz de Medeiros',
#  'P.A.I - Pronto Atendimento IESP - Professora Karelline Izaltemberg Vasconcelos Rosestock e Professor José Airton Xavier Bezerra',
#  'RUNIESP - Professor Wellington Cavalcanti de Araújo\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\n\n\nPESQUISA',
#  'PESQUISA\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAnálise sobre a relevância da massagem e do alongamento em pessoas com dores musuloesqueléticas. - Professora Jeane Odete Freire dos Santos Cavalcanti',
#  'Atendimento a Sociedade na Clinica Escola de Estética - Professora Rafaela Barbosa',
#  'Bullying e Depressão: fatores de risco e intervenções psicossociais no contexto escolar - Professora Maria da Penha de Lima Coutinho',
#  'Câncer Bucal "Abra A BOCA" - Professora Érika Lira De Oliveira',
#  'Escolinha de Futebol - Professor Wellington Cavalcanti de Araújo',
#  'Estabilidade termo-oxidativa de óleos vegetais não convencionais para produção de biocombustíveis - Professor Marco Aurélio Rodrigues de Melo',
#  'Fábrica de Software - Professor Glácio Bezerra Rocha',
#  'Fisioterapia Aquática na Saúde da Mulher - Climatério - Professora Aldeíde de Oliveira Batista',
#  'Gestão do Relacionamento com o Cliente Job Reality - Professor Alessandro Pinon Leitão',
#  'Identificação de patologias na fachada da Igreja São Francisco - João Pessoa - PB - Professor Marco Aurélio Rodrigues de Melo',
#  'Laboratório de Informática e Educação Do UNIESP - Professor Hercílio de Oliveira',
#  'Laboratório de pesquisa em análise do rendimento humano - LAPAR UNIESP PB - Professor Rogério Márcio Luckwu dos Santos',
#  'LACON - Laboratório de Conforto Ambiental - Professora Aline Paiva Montenegro',
#  'LARCERGO - Laboratório de Pesquisas em Acessibilidade e Ergonomia - Professora Larissa Nascimento dos Santos',
#  'Leitura da paisagem urbana e qualidade espacial: O caso de 4 bairros da cidade de João Pessoa - Professor Andrei de Ferrer e Professora Arruda Cavalcanti',
#  'Monitoramento de Dinâmica Costeira para Redução e Contenção do Processo Erosivo da Falésia do Cabo Branco - Litoral Sul de João Pessoa - Professor Williames da Silva Guimarães de Lima',
#  'Open Lab de estudos em criatividade e imaginação - Professor Danilo Andrade de Meneses',
#  'Paisagem Urbana: uma análise crítica da imagem da cidade contemporânea - Professora Marcela Dimenstein',
#  'Qualidade de Vida, Bem-Estar Subjetivo, Resiliência e Representações Sociais no Contexto do Diabetes  Mellitus - Professora Fabrycianne Gonçalves Costa',
#  'Representações Sociais e Qualidade de Vida de Pessoas com Vitiligo: Marcas que não passam em branco - Professor Emerson Araújo do Bú',
#  'Tecnologias para Inovação em EAD',
#  'Uso de Técnicas de Geoprocessamento na gestão de patrimônios histórico da cidade de João Pessoa - PB - Professora Gilmara Danielle de Carvalho Rocha\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\n\n\nRESPONSABILIDADE SOCIAL',
#  'RESPONSABILIDADE SOCIAL\n\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tAção de Responsabilidade social na Comunidade Salinas Ribamar Cabedelo - Professora Maria Adelice da Silva Luz',
#  'LIBRAS - Professor Roberto Coura\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tObservatório de Violências - Professor Jean Patrício da Silva',
#  'Pid - Projeto De Inclusão Digital - Professor Fábio Nicácio de Medeiros\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInstitucional',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário',
#  'Calendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula PRAVALER\n\n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\n\n\n\n\nCopyright ©2025 Sociedade de Ensino Superior da Paraíba Sociedade Simples LTDA',
#  'CPA - Institucional | IESP agora é UNIESP Centro Universitário | Cursos de Graduação e Pós-Graduação\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInstitucional',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário',
#  'Calendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno\n\n\n\n\nInscreva-se',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula \n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\nEducação a Distância\nAtendimento ao Aluno\n\n\n\n\n\n\n\n\n\n\n×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nCPA',
#  '×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nCPA\n\n\n\n\n\nHome\nInstitucional\nCPA',
#  'Comissão Própria de Avaliação (CPA) do UNIESP\nO SINAES instituído pela Lei nº. 10.861 de 14 de abril de 2004 estabeleceu, em seus Artigos 11º e 12º, a formação, em cada Instituição de Ensino Superior, de uma Comissão Própria de Avaliação (CPA).',
#  'A Portaria MEC n.º 2.051, de 09 de julho de 2004, regulamentou os procedimentos de avaliação do Sistema Nacional de Avaliação da Educação Superior (SINAES), instituído na Lei no 10.861, de 14 de abril de 2004, nos Artigos 7º e 8º.',
#  'Nesse contexto, a CPA do UNIESP é parte integrante do SINAES, estabelecendo um elo entre a autoavaliação e o conjunto do sistema de avaliação da educação superior brasileira.\nRELATO INSTITUCIONAL\nPORTARIA DE NOMEAÇÃO\nRELATÓRIO DA CPA',
#  'MEMBROS ATUAIS DA CPA\nA CPA da IES foi nomeada pela PORTARIA/UNIESP/Nº 16 /2024-REITORIA de 28/08/2024, e está assim composta:\n\n \n\n\n\n\n\nRicardo Berilo Bezerra Borba\n\nCoordenador da CPA UNIESP e Representando Docente',
#  'Maria do Socorro Florêncio Henriques\n\nRepresentando Docente\n\n\n\n\n\n\n\n\n\n\n\nLuiz Cláudio da Silva Aguiar Filho\n\nRepresentando Discente\n\n\n\n\n\n\n\n\n\n\n\nLara Maria Nunes de Moura Lobo\n\nRepresentando Discente\n\n\n\n\n\n \n\n\n\n\n\nBerta Maribondo',
#  'Berta Maribondo\n\nRepresentante sociedade civil\n\n\n\n\n\n\n\n\n\n\n\nNilsonete Gonçalves Lucena Ferreira\n\nRepresentante sociedade civil\n\n\n\n\n\n\n\n\n\n\n\nBruno Sérgio da Silva Costa\n\nRepresentante Técnico Administrativo\n\n\n\n\n\n\n\n\n\n\n\nRejane Patrício da Silva',
#  'Rejane Patrício da Silva\n\nRepresentante dos profissionais técnico-administrativos\n\n\n\n\n\n \n\n\n\n\n\n\n \n\n\n\nREGULAMENTO CPA\nBAIXE O\xa0REGULAMENTO AQUI. \n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInstitucional',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário',
#  'Calendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula PRAVALER\n\n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\n\n\n\n\nCopyright ©2025 Sociedade de Ensino Superior da Paraíba Sociedade Simples LTDA',
#  'CEUA - Institucional | IESP agora é UNIESP Centro Universitário | Cursos de Graduação e Pós-Graduação',
# ...
#  'ospitais de média e alta complexidade, serviços domiciliares, clínicas de particulares, bem como, atuar em consultório próprio ofertando vacinas, curativos especializados, enfermagem estética, consultoria em amamentação, Enfermagem em Práticas Integr',
#  'oria em amamentação, Enfermagem em Práticas Integrativas e Complementares (Acupuntura, Fitoterapia, Toque Terapêutico, Musicoterapia), entre outros serviços.',
#  'Os concursos públicos estão em alta para a classe de enfermagem, com salários iniciais que chegam a R$ 5.744,76 (EBSERH- Empresa Brasileira de Serviços Hospitalares).',
#  'Diferenciais do curso de Enfermagem do UNIESP\n\nESTRUTURA',
#  'Salas de aula com equipamentos multimídia e auditórios;\nLaboratórios de ensino para área de saúde: anatomia (peças sintéticas e cadavéricas), microbiologia, microscopia e bioquímica.',
#  'Laboratório de habilidades: Laboratório de Enfermagem em Semiologia e Semiotécnica e Laboratório de Enfermagem em Práticas Avançadas.',
#  'Biblioteca com recursos informáticos adequados, com acervo bibliográfico atualizado sobre Enfermagem e áreas correlatas de conhecimento, assinaturas correntes de periódicos, e responsável pela preservação da produção docente e discente do curso;',
#  'Consultório de Enfermagem, ambiente inserido na Clínica Integrada de Saúde do UNIESP, garante um espaço único de vivência com dos discentes com os usuários do serviço.\nAmplo estacionamento gratuito.',
#  'PROJETOS DE PESQUISA E EXTENSÃO',
#  'PAI - Pronto Atendimento Institucional UNIESP - busca atender aos alunos e colaboradores da Instituição em caso de urgências clinicas (hiperglicemia, hipoglicemia, hipertensão, hipotensão, outros), em situações de emergência e ainda iniciar as mano',
#  'em situações de emergência e ainda iniciar as manobras de Reanimação Cardiopulmonar e acionar a cadeia de socorro local.',
#  'Práticas do saber: alunos extensionistas atuam no Consultório de Enfermagem inserido na Clínica Escola de Saúde do UNIESP prestando atendimento a comunidade em geral e acadêmica.',
#  'AlegrArte: o cuidar humanizado com alegria e arte. Os alunos realizam atividades de arte e terapia em entidades que apoiam crianças com câncer.',
#  'Ninjas da Anatomia: grupo de professores, profissionais e alunos da área da saúde que atuam na área da anatomia humana de forma lúdica, integrando a teoria e prática além da sala de aula, e ainda, atuando na pesquisa com inúmeras\xa0 publicações de liv',
#  'uando na pesquisa com inúmeras\xa0 publicações de livros através da coleção Catarina Maria.',
#  "PARCERIAS\nConvênios celebrados com Hospitais, UBS's, incluindo hospitais de João Pessoa, Cabedelo, Mamanguape e Guarabira, ampliando as possibilidades de atuação nos campos de estágios em diversos âmbitos da Enfermagem (Gestão e Saúde Pública).",
#  'ENCAMINHAMENTO PROFISSIONAL\nNUPS – Acompanhamento psicológico, pedagógico e psicopedagógico durante todo o seu curso;',
#  'Núcleo de carreiras - encaminhamento constante dos alunos para estágios extracurricular e empregos devido ao contato com empresários e empresas da região;\n\xa0\nACONSELHAMENTO VOCACIONAL\nAPOIO E SERVIÇOS PARA OS ALUNOS',
#  'Núcleo de carreiras - Encaminhamento constantemente de alunos para empresas ou para estágios ou para empregos. Temos parceria com milhares de empresas, tudo para ajudar o aluno a desenvolver ainda mais sua vida profissional e acadêmica.',
#  'NUPS - Oferecemos dentro da instituição acompanhamento psicológico, pedagógico e psicopedagógico durante todo o seu curso caso você precise.',
#  'Aconselhamento vocacional: O UNIESP Centro Universitário disponibiliza aos alunos profissionais capacitados para orientar o aluno em decisões importantes na sua jornada acadêmica.',
#  'Internacionalização: A instituição oferece a seus alunos a possibilidade de realizar intercâmbios, é sua oportunidade de trocar conhecimento e conhecer outros países.',
#  'Clínica Escola: A clínica Escola do UNIESP oferece atendimento gratuito a seus alunos nas mais diversas áreas de saúde como, odontologia, fisioterapia, enfermagem, atendimento psicológico e outros.',
#  'Coordenação de fácil acesso: Aqui no UNIESP você tem acesso ao seu coordenador de uma forma simples e sem burocracia, você não precisa marcar horário nem de outros processos para conversar com o coordenador do seu curso como em outras instituições,',
#  'denador do seu curso como em outras instituições, acreditamos que o ensino não deve ter barreiras.',
#  'Inscreva-se\n\n\n\n\n\n\n Inscreva-se\n\n\n\n\n\t\t\t\t\t\t\t\tCoordenadora do Curso\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n Profª. Patrícia Tavares de Lima\n\n\nCurrículo Lattes coordenfermagem@iesp.edu.br (83) 2106-3834 \n\n\n\n\n\nManual do Aluno\nEmpresas Conveniadas\n\n\n\n\n QUERO SABER MAIS',
#  'QUERO SABER MAIS\n\n\n\nEstrutura\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInstitucional',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário',
#  'Calendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula PRAVALER\n\n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\n\n\n\n\nCopyright ©2025 Sociedade de Ensino Superior da Paraíba Sociedade Simples LTDA',
#  'Engenharia Civil - Graduação | IESP agora é UNIESP Centro Universitário | Cursos de Graduação e Pós-Graduação',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD',
#  'Dirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula \n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\nEducação a Distância\nAtendimento ao Aluno\n\n\n\n\n\n\n\n\n\n\n×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nEngenharia Civil',
#  '×\n\n\nBuscar\n\n\n\n\n\n\n \n\n\n\n\n\n\nEngenharia Civil\n\n\n\n\n\nHome\nCursos\nGraduação\n\n\n\n\n\n\n\n\n\n\n\n\n\nSobre o curso\n\n\nGraduação - Bacharelado - Presencial\n  5 anos',
#  'O Bacharel em Engenharia Civil é um profissional Engenheiro de grau superior, preocupado com a aplicação do conhecimento científico da matemática, física, química, biologia, administração, antropologia, com criatividade de solucionar problemas técni',
#  'ia, com criatividade de solucionar problemas técnicos no ramo de construção de casas, prédios, estradas, portos, barragens, pontes, plataformas, túneis, viadutos entre outros. É um profissional que projeta, analisa, gerencia, executa, fiscaliza e aco',
#  'ojeta, analisa, gerencia, executa, fiscaliza e acompanha todas as etapas de uma obra.',
#  'ATO REGULATÓRIO\nAutorizaçãoPortaria MEC 721 - (27/11/2014) - DOU 28/11/2014\n\xa0\nReconhecimento\nPortaria do MEC 608 - (09/09/2019)',
#  'Mercado de Trabalho',
#  'A engenharia civil é uma carreira com intensa procura pelo mercado, devido à variedade de polos de trabalho, tanto nas organizações governamentais como naquelas não governamentais. Assim, as lacunas por engenheiros em nosso país demandam a necessida',
#  'por engenheiros em nosso país demandam a necessidade, sempre urgente, por trabalhadores para o setor, fazendo da Engenharia Civil uma profissão não apenas requisitada, mas extremamente essencial.',
#  'Diferenciais do curso de Engenharia Civil do UNIESP\n\nCENTRO UNIVERSITÁRIO CONCEITO MÁXIMO NO MEC\xa0⭐⭐⭐⭐⭐\nPROJETOS',
#  'EDIFIC - Nesta Empresa Júnior os alunos atendem a empresas reais do mercado Paraibano, auxiliando nos mais diversos projetos da área de engenharia.',
#  'Novos Engenheiros - É um projeto prático que visa tornar os novos engenheiros consciente do seu papel dentro da sociedade. Nele, os alunos prestam auxílio à comunidade local em atividades do dia a dia em que a engenharia está presente, fornecendo co',
#  'a em que a engenharia está presente, fornecendo conhecimentos básicos da área. Todos os eventos do curso buscam arrecadar doações para serem distribuídas nas comunidades. O projeto também preza pelo lado da sustentabilidade, como o aproveitamento de',
#  'ado da sustentabilidade, como o aproveitamento de água; energia elétrica e solar; e incentiva pesquisas inéditas como a que já acontece no campus, como óleo combustível para motores feito de oitizeiro.',
#  'Aulas de campo - Visita a obras e acidentes geográficos dentro da cidade, verificando causas desses problemas e apontado sua resolução.',
#  'Semana de Engenharia - Semana de atividades onde a instituição recebe palestras, workshops, e representantes das maiores empresas de engenharia, afim de compartilhar\xa0conhecimento e experiências com os alunos.',
#  'Campeonatos de Engenharia (concreto, pontes e topografia) - Durante a semana de engenharia o aluno\xa0tem a possibilidade de iniciar o\xa0treinamento para a competição nacional. Além disso, coloca todo conhecimento adquirido na sala de aula em prática.',
#  'ESTRUTURA',
#  'Unidade de Ensino Prático em Engenharia (UEPE) - Complexo, dentro do campus, formado por laboratórios de desenho, física, eletricidade, química, geologia, topografia, hidrologia, hidráulica, materiais de construção, mecânica dos solos e concreto.',
#  'CENTRO DE TECNOLOGIA UNIESP - Um bloco inteiro com máquinas de alto desempenho onde os alunos usam os mais recentes softwares do mercado, colocando em prática as atividades dos cursos.',
#  'Núcleo de Iniciação Cientifica - Grupo de professores que presta apoio ao aluno que deseja desenvolver projetos científicos. Além de contar com os professores, ele pode também contar com toda a estrutura de laboratórios do Centro Universitário.',
#  'Projetos Integradores - O aluno cria projetos com auxílio dos professores dentro do UNIESP que pode ser aplicado no mercado real.',
#  'Biblioteca referência no estado da Paraíba, muito procurada também pela comunidade externa e central de Informação com acervo atualizado e assinatura de periódicos da área.\nSalas multimídia.\nAmplo estacionamento gratuito.',
#  'ENCAMINHAMENTO PROFISSIONAL\n\nNUPS – Acompanhamento psicológico, pedagógico e psicopedagógico durante toda Graduação.\nNúcleo de Carreiras - Encaminhamento dos alunos para estágios e empregos devido ao contato com empresários e empresas da região.',
#  'PARCERIAS',
#  'Convênio com o IPHAEP\xa0- Os alunos são responsáveis pela perícia estrutural nos imóveis antigos da cidade de João Pessoa.\nVisitas Técnicas - Os alunos visitam as principais empresas da região, afim de visualizar na prática o que vem em sala de aula.',
#  'APOIO E SERVIÇOS PARA OS ALUNOS',
#  'Núcleo de carreiras - Encaminhamento constantemente\xa0de alunos para empresas ou para estágios ou para empregos. Temos parceria com milhares de empresas, tudo para ajudar o aluno a desenvolver ainda mais sua vida profissional e acadêmica.',
#  'NUPS -\xa0Oferecemos dentro da instituição acompanhamento psicológico, pedagógico e psicopedagógico durante todo o seu curso caso você precise.',
#  'Aconselhamento vocacional: O UNIESP Centro Universitário disponibiliza aos alunos profissionais capacitados para orientar o aluno em decisões importantes na sua jornada acadêmica.',
#  'Internacionalização: A instituição oferece a seus alunos a possibilidade de realizar intercâmbios, é sua oportunidade de trocar conhecimento e conhecer outros países.',
#  'Clínica Escola: A clínica Escola do UNIESP oferece atendimento gratuito a seus alunos nas mais diversas áreas de saúde como, odontologia, fisioterapia, enfermagem, atendimento psicológico e outros.',
#  'Coordenação de fácil acesso: Aqui no UNIESP você tem acesso ao seu coordenador de uma forma simples e sem burocracia, você não precisa marcar horário nem de outros processos para conversar com o coordenador do seu curso como em outras instituições,',
#  'denador do seu curso como em outras instituições, acreditamos que o ensino não deve ter barreiras.',
#  'Inscreva-se\n\n\n\n\n\n\n Inscreva-se\n\n\n\n\n\t\t\t\t\t\t\t\tCoordenador do Curso\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n Prof. Giuseppe Vasconcelos\n\n\nCurrículo Lattes coordengcivil@iesp.edu.br (83) 2106-3800 \n\n\n\n\n\nManual do Aluno\nEmpresas Conveniadas\n\n\n\n\n QUERO SABER MAIS',
#  'QUERO SABER MAIS\n\n\n\nEstrutura\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nInstitucional',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário',
#  'Calendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula PRAVALER\n\n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\n\n\n\n\nCopyright ©2025 Sociedade de Ensino Superior da Paraíba Sociedade Simples LTDA',
#  'Estética e Cosmética - Graduação | IESP agora é UNIESP Centro Universitário | Cursos de Graduação e Pós-Graduação',
#  'Institucional\n\nCentro Universitário\nEstrutura\nPolos\nBiblioteca\nColuna Ponto de Vista\nCOOPERE\nPublicações\nCPA\nCEUA\nENADE\nComitê de Ética\nDCE e DAS\n\nDirigentes\nSetores e telefones\nDPO - LGPD',
#  'Dirigentes\nSetores e telefones\nDPO - LGPD\n\nCalendário\n\nCALENDÁRIO ACADÊMICO DO EAD\nCalendário acadêmico\n\n\nProjetos\nNotícias\n \n\n\nCursos\n\nGraduação\n\nPresencial\nSemipresencial\nEAD\n\n\nPós-Graduação\n\nPresencial\nEAD\n\n\nCursos Livres\n\n\nManual do Aluno',
#  'Cursos Livres\n\n\nManual do Aluno\n\n\n\n\nInscreva-se\n\nInscreva-se\nENEM\nVestibular Online\nTransfira para o UNIESP\n2ª Graduação\nRetorno ao curso\nBolsas e Financiamentos\nConsulte seu Resultado\nMatrícula \n\n\nServiços',
#  'Serviços\n\nAluno Online – Graduação\nAluno Online – Pós\nProfessor Online\nPlataforma de Aprendizagem',
#  'Biblioteca\nEducação Corporativa\nInternacionalização\nNúcleo de Carreiras\nEstágios\nNUPS\nClínica Escola\nÁrea do Egresso\nAtendimento on-line\nAutenticidade\n\n \n\nEducação a Distância\nAtendimento ao Aluno\n\n\n\n\n\n\n\n\n\n\n×\n\n\nBuscar',
#  ...]

# %%
embedding = HuggingFaceHubEmbeddings(huggingfacehub_api_token=os.getenv("huggin"),model="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")

vector_db = FAISS.from_texts(texts=text,embedding=embedding)
# Out:
# /home/lucas/Área de Trabalho/llm_curso/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)

# %%
RAG_PROMPT_TEMPLATE = """Use o contexto abaixo **E** seu conhecimento geral para responder:
        
        {context}
        
        Pergunta: {question}

        Caso a questão não seja baseada no contexto, utilize seus conhecimento gerais para responder a pergunta do usuário.


        args:
                 institucional:str = Field(description="retorna link sobre instituicional. link:https://www.iesp.edu.br/institucional/. use os examples para saber o que colocar apos o ultimo /",
                              examples=["centro universitário:no link inves de centro universitario coloque a-faculdade,biblioteca,estrutura,polos,coopere,publicacoes,cpa(comissão Própria de avaliação),ceua(comitê de ética na utilização animal),enade,dce-e-das,dirigentes,setores-e-telefones,dpo-lgpd(oficial de proteção de dados),calendarios,projetos,noticias"])
                cursos_presencial:str = Field(description="retorna link sobre cursos ou cursos presencias. link: https://www.iesp.edu.br/cursos/graduacao/modalidade/presencial")
                cursos_semipresencial:str = Field(description="retorna link sobre cursos semipresenciais. link:https://www.iesp.edu.br/cursos/graduacao/modalidade/semipresencial")
                cursos_ead:str = Field(description="retorna link sobre os cursos ead. link: https://www.iesp.edu.br/cursos/graduacao/modalidade/ead")
                cursos_posgraducao_presencial:str = Field(description="retorna link sobre cursos de pos graduação ou pos graduação presencial. link: https://www.iesp.edu.br/cursos/pos-graduacao/modalidade/presencial")
                cursos_posgraduacao_ead:str = Field(description="retorna link sobre cursos pos graduação ead. link:https://www.iesp.edu.br/cursos/pos-graduacao/modalidade/ead")
                servicos:str = Field(description="retorna link sobre os serviços do site. link:https://www.iesp.edu.br/servicos/. use os examples para saber o que colocar apos o ultimo /",
                         examples=["educação-corporativa,internacionalizacao,nucleo-de-carreiras,estagios,nups,clinicaescola"])
                inscrevase:str = Field(description="retorna link sobre increvase. link:https://www.iesp.edu.br/ingresso/inscreva-se. use os examples para saber quais são os assunstos/ tipos de inscrição.",
                           examples=["matricula,enem,vestibular online,2 graduação,vestibular online,retorno ao curso,bolsas e financiamentos,consulte seu resultado"])

        IMPORTANTE: utilize os args para responder a pergunta do usuário quando achar necessário fornecer estes links para o usuário.
        CUIDADO: Não forneça sites que nao sejam sobre o assunto perguntado pelo usuário e formate adequadamente a resposta. exemplo: [link](url) nao deixe '\n\n' no final dos links por exemplo.     

        Resposta (seja natural e combine informações quando necessário):"""

prompt_template = PromptTemplate.from_template(RAG_PROMPT_TEMPLATE)

# %%
retriever = RetrievalQA.from_chain_type(
            llm=chat,
            retriever=vector_db.as_retriever(search_type="mmr"),
            chain_type="stuff",
            chain_type_kwargs={"prompt":prompt_template},
            verbose=True
        )

# %% [markdown]
# ### Gradio

# %%
def response(text,retriever=retriever):
    texto = retriever.run(text)
    return texto

# %%
import gradio as gr 

with gr.Blocks() as app:
    gr.Markdown("# CHATBOT UNIESP, BEM VINDO!")
    with gr.Row(equal_height=True):
        texto= gr.Textbox(label="faça sua pergunta")
        button = gr.Button("Enviar",variant="primary")
    
    area = gr.Textbox(label="resposta")
    
    button.click(
        fn=response,
        inputs=[texto],
        outputs=[area]
    )

app.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7870
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7870/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# > Entering new RetrievalQA chain...
# /home/lucas/Área de Trabalho/llm_curso/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# > Finished chain.
